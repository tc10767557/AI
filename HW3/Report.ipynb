# %% [markdown]
# <a href="https://colab.research.google.com/github/tc10767557/AI/blob/main/HW3/Report.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Teagan Clark
#
# Dr. Forouraghi
#
# Artificial Intelligence
#
# 21 October 2025

# %% [markdown]
# #Assignment 3
# This assignment revolved around A* and Greedy Best-First searches in the given maze. This document contains my findings for the three problems. Also included are screenshots of the maze pathings created in the PyCharm IDE as such images will not be generated correctly when using Google Colab.

# %% [markdown]
# ##Problem 1

# %% [markdown]
# For problem 1, I used the existing AStarMaze code and compared the performance of the two algorithms for the maze image that was attached to the assignment. We can see that A* and the Greedy BFS both performed similarly to the example image. Where in this case, A* was definitely the more optimal of the two algorithms in terms of their shortest paths.![Picture1.png](data:image/png;base64,...)
# ![Picture2.png](data:image/png;base64,...)

# %% [markdown]
# ##Problem 2

# %% [markdown]
# This one allowed for diagonal moves as well as the existing cardinal directions. It also made the choice of direction random. I used problem 1’s code as a basis here. We can see that with the A* algorithm, there is a slight improvement when rounding the corner of the wall, while Greedy BFS makes a much more noticeable improvement thanks to the addition of diagonal movements, though still clearly not as optimal as A*.
#
# ![Picture3.png](data:image/png;base64,...)![Picture4.png](data:image/png;base64,...)

# %% [markdown]
# ##Problem 3

# %% [markdown]
# For problem 3, I modified the code from 2 to have an α and β parameter which could be adjusted. I ran the existing A* and Greedy BFS, but also added another version of A* with a weighted β of 3 instead of the standard 1. Though it didn’t make a difference in the resulting path here, on other mazes it is possible for it to solve the maze faster and have a difference in pathing.
#
# ![Picture5.png](data:image/png;base64,...)![Picture6.png](data:image/png;base64,...)![Picture7.png](data:image/png;base64,...)
